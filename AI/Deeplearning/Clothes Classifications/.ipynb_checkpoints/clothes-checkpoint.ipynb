# %% [markdown]
# ## CONTENT
# - [1- PACKAGES](#1)
# - [2- DATA](#2)
#    - [2.1- Get Data](#2.1)
#    - [2.2- Check Data](#2.2)
#    - [2.3- Adjust Data](#2.3)
# - [3- MODEL](#3)
#    - [3.1- Fully Connected Model](#3.1)
#    - [3.2- Convolutional Neural Network](#3.2)

# %% [markdown]
# <a name='1'></a>
# ### 1- PACKAGES

# %%
import tensorflow as tf 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelBinarizer
import seaborn as sns
import numpy as np

# %% [markdown]
# <a name='2'></a>
# ### 2- DATA

# %% [markdown]
# Data Composite of :
# * 60000 Train Examples
# * 10000 Test Examples
# * 10 Classes:
#   * T-shirt/top
#   * Trouser
#   * Dress
#   * Coat
#   * Sandal
#   * Shirt
#   * Sneaker
#   * Bag
#   * Ankle boot

# %% [markdown]
# <a name='2.1'></a>
# #### 2.1- Get DATA

# %%
clothes = tf.keras.datasets.fashion_mnist
(X_train,y_train),(X_test,y_test) = clothes.load_data()

# %% [markdown]
# <a name='2.3'><a>
# #### 2.2- Check Data

# %%
n_train = X_train.shape[0]
n_test  = X_test.shape[0]
print("Triain examples : ",n_train)
print("Test   examples : ",n_test)
# Out:
# Triain examples :  60000
# Test   examples :  10000

# %%
classes = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
col = 5
row = 5
fig, ax = plt.subplots(row,col, figsize=(20,20))
indexs  = np.random.randint(0, n_test, row*col)
count   = 0
for i in range(row):
    for j in range(col):
        ax[i, j].imshow(X_test[indexs[count]], cmap='gray') 
        ax[i, j].set_title(f'{y_test[indexs[count]]} -> {classes[y_test[indexs[count]]]}')
        ax[i, j].axis(False)
        count+=1

# %% [markdown]
# <a name='2.3'></a>
# #### 2.3- Adjust Data

# %%
(X_train,X_test) = (X_train.astype('float32')/255.0,X_test.astype('float32')/255.0)

# %% [markdown]
# ##  3- MODEL

# %% [markdown]
# <a name='3.1'></a>
# #### 3.1- Fully Connected Model

# %%
model1 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
predict = tf.keras.Sequential([
        model1,
        tf.keras.layers.Softmax()
    ])

# %%
model1.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
hist = model1.fit(X_train, y_train, epochs=10, batch_size=64 ,validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5202 - accuracy: 0.8189 - val_loss: 0.4697 - val_accuracy: 0.8354
# Epoch 2/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3933 - accuracy: 0.8605 - val_loss: 0.3980 - val_accuracy: 0.8580
# Epoch 3/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3494 - accuracy: 0.8741 - val_loss: 0.4081 - val_accuracy: 0.8546
# Epoch 4/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3252 - accuracy: 0.8816 - val_loss: 0.3654 - val_accuracy: 0.8704
# Epoch 5/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3063 - accuracy: 0.8870 - val_loss: 0.3513 - val_accuracy: 0.8726
# Epoch 6/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2899 - accuracy: 0.8940 - val_loss: 0.3546 - val_accuracy: 0.8698
# Epoch 7/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2799 - accuracy: 0.8963 - val_loss: 0.3531 - val_accuracy: 0.8681
# Epoch 8/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2690 - accuracy: 0.9009 - val_loss: 0.3348 - val_accuracy: 0.8781
# Epoch 9/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2553 - accuracy: 0.9051 - val_loss: 0.3530 - val_accuracy: 0.8772
# Epoch 10/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2489 - accuracy: 0.9081 - val_loss: 0.3382 - val_accuracy: 0.8803

# %%
model1.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3382 - accuracy: 0.8803
# [0.33816689252853394, 0.880299985408783]

# %%
predict(np.array([X_test[0]]))
# Out:
# <tf.Tensor: shape=(1, 10), dtype=float32, numpy=
# array([[4.2138609e-07, 1.9625300e-07, 6.5530030e-06, 4.6704240e-06,
#         3.8690806e-07, 2.5678597e-02, 2.5001598e-06, 3.1185610e-02,
#         9.4113941e-04, 9.4217986e-01]], dtype=float32)>

# %%
plt.style.use('pepso_light')
fig, ax = plt.subplots(2, 1, figsize=(15,10))
ax[0].plot(hist.history['accuracy'],label='tra/acc')
ax[0].plot(hist.history['val_accuracy'],label='val/acc')
ax[0].set_title("Accuracies")
ax[0].legend()
ax[1].plot(hist.history['loss'],label='tra/lss')
ax[1].plot(hist.history['val_loss'],label='val/lss')
ax[1].set_title("Lossies")
ax[1].legend()
plt.show()

# %%
col = 5
row = 5
fig, ax = plt.subplots(row,col, figsize=(10,10))
indexs  = np.random.randint(0, n_test, row*col)
count   = 0
for i in range(row):
    for j in range(col):
        pred = np.argmax(predict(np.array([X_test[indexs[count]]])))
        if pred == y_test[indexs[count]] : 
            color = 'green'
        else :
            color = 'red'
        ax[i, j].imshow(X_test[indexs[count]], cmap='gray') 
        ax[i, j].set_title(f'{classes[pred]}',color=color)
        ax[i, j].axis(False)
        count+=1

# %%
wrong = []
for i in range(n_test):
    if np.argmax(predict(np.array([X_test[i]]))) != y_test[i]:
        wrong.append(i)

# %%
col = 5
row = 5
fig, ax = plt.subplots(row,col, figsize=(10,10))
indexs = np.random.choice(wrong,col*row)
count   = 0
for i in range(row):
    for j in range(col):
        pred = np.argmax(predict(np.array([X_test[indexs[count]]])))
        if pred == y_test[indexs[count]] : 
            color = 'green'
        else :
            color = 'red'
        ax[i, j].imshow(X_test[indexs[count]], cmap='gray') 
        ax[i, j].set_title(f'{classes[pred]}',color=color)
        ax[i, j].axis(False)
        count+=1

# %%
preds = np.argmax(predict(X_test),axis=1)

# %%
conf_mat = tf.math.confusion_matrix(preds,y_test).numpy()
fig,ax = plt.subplots(figsize=(16,16))
sns.heatmap(conf_mat/conf_mat.sum(axis=0),cmap = 'Blues',annot=True,fmt = '.2%',linewidth=1,ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('True')
ax.set_title("Confucion matrix accuracy")
ax.set_xticklabels(classes)
ax.set_yticklabels(classes)
plt.show()
